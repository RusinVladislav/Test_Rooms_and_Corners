# %%
from mean import draw_plots
from constants import FILE_URL

table_data = draw_plots(FILE_URL)
name_colum = [item for item in table_data] 
table_data.plot.area(figsize=(12, 4), subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)
